# %%
from pathlib import Path
from os import listdir

main_path = Path("/home/luckagianvechio/Documents/Material Estudo TCC/IIT CDIP/images.a.a/imagesa/a/a")
a_path = Path("a/")
a_img_folder_path = [main_path / a_path / Path(pt) for pt in listdir(main_path / a_path)]
a_img_path = []
for pt in a_img_folder_path:
    files = listdir(pt)
    for file in files:
        if not file.split(".")[1] == "xml":
            a_img_path.append(pt / file)

# %%
a_img_path[0]
# Out:
# PosixPath('/home/luckagianvechio/Documents/Material Estudo TCC/IIT CDIP/images.a.a/imagesa/a/a/a/aaa20d00/522868231+-8231.tif')

# %%
testinho = a_img_path[0]
str(testinho)
# Out:
# '/home/luckagianvechio/Documents/Material Estudo TCC/IIT CDIP/images.a.a/imagesa/a/a/a/aaa20d00/522868231+-8231.tif'

# %%
from ocr_tools import get_ocr_word_box_list, preprocess_image, resize_image, read_image

test_image = read_image(a_img_path[0])
get_ocr_word_box_list(a_img_path[0])
# Out:
# [{'bbox': [0, 0, 864, 1146], 'text': ''},
#  {'bbox': [31, 21, 830, 1055], 'text': ''},
#  {'bbox': [31, 21, 830, 234], 'text': ''},
#  {'bbox': [31, 21, 830, 52], 'text': ''},
#  {'bbox': [31, 22, 87, 52], 'text': 'Altempt'},
#  {'bbox': [88, 22, 111, 52], 'text': 'doe'},
#  {'bbox': [193, 26, 223, 29], 'text': 'em'},
#  {'bbox': [780, 21, 811, 52], 'text': 'age’'},
#  {'bbox': [816, 25, 830, 48], 'text': '7}'},
#  {'bbox': [226, 218, 636, 234], 'text': ''},
#  {'bbox': [226, 218, 260, 234], 'text': 'RJ.'},
#  {'bbox': [282, 218, 295, 234], 'text': 'RE'},
#  {'bbox': [596, 218, 636, 234], 'text': 'ERT'},
#  {'bbox': [165, 267, 433, 281], 'text': ''},
#  {'bbox': [165, 267, 433, 281], 'text': ''},
#  {'bbox': [165, 267, 199, 279], 'text': 'Alert'},
#  {'bbox': [204, 267, 239, 279], 'text': 'Date:'},
#  {'bbox': [298, 267, 370, 279], 'text': 'December'},
#  {'bbox': [375, 267, 395, 281], 'text': '19,'},
#  {'bbox': [400, 267, 433, 279], 'text': '1997'},
# ...

# %%
preprocess_image(resize_image(test_image)[0])
# Out:
# array([[  0,   0, 255, ..., 255, 255, 255],
#        [  0,   0, 255, ..., 255, 255, 255],
#        [  0,   0, 255, ..., 255, 255, 255],
#        ...,
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255]], dtype=uint8)

# %%
from PIL import Image

Image.fromarray(preprocess_image(resize_image(test_image)[0]))
# Out:
# <PIL.Image.Image image mode=L size=864x1146>
